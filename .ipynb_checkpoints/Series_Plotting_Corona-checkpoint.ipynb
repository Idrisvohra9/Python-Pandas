# %%
import pandas as pd

data = [16000,8000,120,10,30,40,580,1100,300,100,30,12]
months = ["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]

s = pd.Series(data, index=months)

s.plot(kind='pie',title="Corona Cases of Gujarat in 2021",xlabel="months",ylabel="data")
# Out:
# <AxesSubplot:title={'center':'Corona Cases of Gujarat in 2021'}, ylabel='data'>
